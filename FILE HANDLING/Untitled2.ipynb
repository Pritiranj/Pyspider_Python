# %%
fobj=open('sunday.txt','r')
print(fobj.read(4))
print(fobj.tell())
# Out:
# I ha
# 4

# %%
print(fobj.readlines())
print(fobj.tell())
# Out:
# []
# 71

# %%
con='we are very bad boy'
fobj.write(con)
fobj.close()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[18], line 2
#       1 con='we are very bad boy'
# ----> 2 fobj.write(con)
#       3 fobj.close()
#
# UnsupportedOperation: not writable
