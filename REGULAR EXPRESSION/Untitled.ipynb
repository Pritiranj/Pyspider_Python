# %%
s='re-mock re-mock'
import re

# %%
import re

s = "hello"
v = re.match('h', s)
print(v)  # Output: None
# Out:
# <re.Match object; span=(0, 1), match='h'>

# %%
re.search('h',s)
# Out:
# <re.Match object; span=(0, 1), match='h'>

# %%
re.findall('l',s)
# Out:
# ['l', 'l']

# %%
 re.split('l',s)
# Out:
# ['he', '', 'o']

# %%
re.sub('l','p',s)
# Out:
# 'heppo'

# %%
re.subn('l','z',s)
# Out:
# ('hezzo', 2)

# %%
for ans in  re.finditer('l',s):
    print(ans)
# Out:
# <re.Match object; span=(2, 3), match='l'>
# <re.Match object; span=(3, 4), match='l'>

# %%
cobj=re.compile ('l')
cobj.findall(s)
# Out:
# ['l', 'l']

# %%
s='a-b2)D\ty(u2\n84p4f'

# %%
#for finding the 1st ele only ,i will provide empty list if we find except 1st letter

#re.findall('^b',s)
re.findall('^a',s)
# Out:
# ['a']

# %%
re.findall('f$',s)
# Out:
# ['f']

# %%
s='a ab abc abbc abbbc abbbc'

# %%
#find the 

re.findall('ab*c',s)
# Out:
# ['a', 'ab', 'abc', 'abbc', 'abbbc', 'abbbc']

# %%
re.findall('a?b',s)
# Out:
# ['ab', 'ab', 'ab', 'b', 'ab', 'b', 'b', 'ab', 'b', 'b']

# %%
re.findall('ab?',s)
# Out:
# ['a', 'ab', 'ab', 'ab', 'ab', 'ab']

# %%
re.findall('ab{2}',s)
# Out:
# ['abb', 'abb', 'abb']

# %%
s='H4el ^/ow)o7rl@d'
import re

# %%
re.findall('\^',s)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\^'
# <>:1: SyntaxWarning: invalid escape sequence '\^'
# C:\Users\Asus\AppData\Local\Temp\ipykernel_16180\3556491173.py:1: SyntaxWarning: invalid escape sequence '\^'
#   re.findall('\^',s)
# ['^']

# %%
from abc import ABC,abstarctmethod

class Tv:
    @abstractmethod
    def power(self):
        pass
class ch1(Tv):
    def channel(self):
        print('hi')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from abc import ABC,abstarctmethod
#       3 class Tv:
#       4     @abstractmethod
#       5     def power(self):
#
# ImportError: cannot import name 'abstarctmethod' from 'abc' (C:\Users\Asus\anaconda3\Lib\abc.py)

# %%
num=16
val=0

while val*val != num+1:
    if val *val == num:
        print('yes')
        break
