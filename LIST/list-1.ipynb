# %%
l=[3,5,1,4,2]
for ind in range(len(l)//2):
    l[ind],l[-ind-1]=l[-ind-1],l[ind]
print(l)
# Out:
# [2, 4, 1, 5, 3]

# %%
l=[3,5,1,4,2]
ind=0
while ind  != len(l)//2:
    l[ind],l[-ind-1]=l[-ind-1],l[ind]
    ind+=1
print(l)
# Out:
# [2, 4, 1, 5, 3]

# %%
l=[1,2,3,4,5]
target=6
for ind1 in range(len(l)):
    for ind2 in range(len(l)):
        if l[ind1]+l[ind2]==target:
            print(l[ind1],l[ind2])
# Out:
# 1 5
# 2 4
# 3 3
# 4 2
# 5 1

# %%
l = [1, 2, 3, 4, 5]
target = 6
num=0
for ind in l:
    num=target-ind
    if num in l:
        print(set(num,ind))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 7
#       5 num=target-ind
#       6 if num in l:
# ----> 7     print(set(num,ind))
#
# TypeError: set expected at most 1 argument, got 2

# %%
l = [1, 2, 3, 4, 5]
target = 6
seen = set()  # To track elements that have been processed
for ind in l:
    num = target - ind
    if num in l and num not in seen:
        print(ind, num)
    seen.add(ind)  # Mark the current element as processed
''
# Out:
# 1 5
# 2 4
# 3 3
# ''
