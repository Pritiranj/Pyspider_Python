# %%
def outer(arg):
    def inner():
        obj=arg()
        return obj
    return inner

@outer
class sunday():
    def __init__(self):
        print('we will attend the class')
    def m1(self):
        print('hello world')

obj=sunday()
obj.m1()
# Out:
# we will attend the class
# hello world

# %%
def outer(arg):
    l=[]
    def inner():
        if len(l)==0:
            obj=arg()
            l.append(obj)
        return l[0]
    return inner

@outer
class sun():
    def __init__(self):
        print('hi')
    def m1(self):
        print('hello')

obj1=sun()
obj2=sun()
obj1.m1()
obj2.m1()
# Out:
# hi
# hello
# hello

# %%
def outer(arg):
    l=[]
    def inner():
        if len(l) == 0:
            obj=arg()
            l.append(obj)
        return l[0]
    return inner

@outer

class sunday:
    def __init__(self):
        print('we will attend')
    def m1(self):
        print('hello')
obj=sunday()
obj.m1()
ob2=.sun()
# Out:
# we will attend
# hello
# hello

# %%
def outer(arg):
    l = []
    def inner():
        if len(l) == 0:
            obj = arg()
            l.append(obj)
        return l[0]
    return inner

@outer
class sunday:
    def __init__(self):
        print('we will attend')
    #def m1(self):
        #print('hello')

obj = sunday()
# Out:
# we will attend
