# %%
#creating class
class SBI:
    branch='marathali'
    IFSC='SBIN00064'
    roi=0.07
#----------------------------------------------------------------------------------------------------------

#intialize obj
    def __init__(self,name,accno,mobno,bal,pin):
        self.name=name
        self.accno = accno
        self.mobno = mobno
        self.bal = bal
        self.pin = pin

#----------------------------------------------------------------------------------------------------------

#creating a obj to display the data
    def details(self):
        print(self.name)
        print(self.accno)
        print(self.mobno)
        print(self.bal)
        print(self.pin)

    
#---------------------------------------------------------------------------------------

#creating a object for withdraw the money
    def withdraw(self):
        if self.pin==self.checkpin():
            amount=int(input('Enter the amount'))
            if 0<=amount<=20000:
                if amount<=self.bal:
                    self.bal-=amount
                    print('Amount Debited')
                    print(f'remaining amount is {self.bal}')
                else:
                    print('Insufficient bal')
            else:
                print('be in your limit')
        else:
            print('Incorrect pin')

    
#----------------------------------------------------------------------------------------------------------
    
#creating a stic methof for ctaking the pin         
    @staticmethod
    def checkpin():
        key=int(input('enter the pin'))
        return key

#----------------------------------------------------------------------------------------------------------  
        
#creating a object to deposite
    def deposite(self):
        if self.checkpin()==self.pin:
            amount=int(input('Enter the amount'))
            if 100<=amount<=50000:
                self.bal+=amount
                print('amount successfully credited')
                print(f'the amount is {self.bal}')
            else:
                print('i can not take')
        else:
            print('incorrect pin')

    
#----------------------------------------------------------------------------------------------------------      
#creating a obj to check the balance
    def checkbal(self):
        if self.checkpin()==self.pin:
            print(f'{self.bal } is your total amount')
        else:
            print('incorrect pin')

#----------------------------------------------------------------------------------------------------------


#creating the obj
cust1=SBI('situ',11111111111,7894544774,4000,5068)
cust2=SBI('banty',22222222222,7788986780,5000,3423)
cust=SBI('mana',3333333333,9583050847,50000,2222)

#----------------------------------------------------------------------------------------------------------

#accesing the objec 
#cust1.withdraw()
#cust1.deposite()
cust2.deposite() 
cust2.checkbal()
# Out:
# enter the pin 3423
# Enter the amount 500
# amount successfully credited
# the amount is 5500
# enter the pin 3423
# 5500 is your total amount
