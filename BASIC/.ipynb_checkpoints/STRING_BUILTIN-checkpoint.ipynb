# %%
s='SITU IS A GOOD boy'

# %%
s.upper()
# Out:
# 'SITU IS A GOOD BOY'

# %%
s.lower()
# Out:
# 'situ is a good boy'

# %%
s.swapcase()
# Out:
# 'situ is a good BOY'

# %%
s.title()
# Out:
# 'Situ Is A Good Boy'

# %%
s.capitalize()
# Out:
# 'Situ is a good boy'

# %%
s.replace('S','@',1)
# Out:
# '@ITU IS A GOOD boy'

# %%
s.split('S')
# Out:
# ['', 'ITU I', ' A GOOD boy']

# %%
s.index('S',1)
# Out:
# 6

# %%
s.index('S',1,len(s))
# Out:
# 6

# %%
s.rindex('S',1,9)
# Out:
# 6

# %%
s.find('s')
# Out:
# -1

# %%
s='he is a good boy'

# %%
s.find('g',2,4)
# Out:
# -1
