# %%
s='SITU IS A GOOD boy'

# %%
s.upper()
# Out:
# 'SITU IS A GOOD BOY'

# %%
s.lower()
# Out:
# 'situ is a good boy'

# %%
s.swapcase()
# Out:
# 'situ is a good BOY'

# %%
s.title()
# Out:
# 'Situ Is A Good Boy'

# %%
s.capitalize()
# Out:
# 'Situ is a good boy'

# %%
s.replace('S','@',1)
# Out:
# '@ITU IS A GOOD boy'

# %%
s.split('S')
# Out:
# ['', 'ITU I', ' A GOOD boy']

# %%
s.index('S',1)
# Out:
# 6

# %%
s.index('S',1,len(s))
# Out:
# 6

# %%
s.rindex('S',1,9)
# Out:
# 6

# %%
s.find('s')
# Out:
# -1

# %%
s='he is a good boy'

# %%
s.find('g',2,4)
# Out:
# -1

# %%
l=[1,2,3,4,5,6]

# %%
l.append(9)

# %%
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 9]

# %%
l.insert(3,'p')

# %%
l
# Out:
# [1, 2, 3, 'p', 10, 10, 10, 4, 5, 6, 9, '1', '2', '3', 'p', 'q', 'r', 's']

# %%
l.extend('pqrs')

# %%
l
# Out:
# [1, 2, 3, 10, 10, 10, 4, 5, 6, 9, '1', '2', '3', 'p', 'q', 'r', 's']

# %%
l.remove('p')

# %%
l
# Out:
# [1, 2, 3, 10, 10, 4, 5, 6, 9, '1', '2', '3', 'p', 'q', 'r', 's']

# %%
l.pop(2)
# Out:
# 3

# %%
l
# Out:
# [1, 2, 10, 4, 5, 6, 9, '1', '2', '3', 'p', 'q', 'r']

# %%
l.count(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 l.count(1,2,3)
#
# TypeError: list.count() takes exactly one argument (3 given)

# %%
l.count('p')
# Out:
# 1

# %%
l.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 l.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
s={1,2,3,4,5,'p'}

# %%
s.add((4,5,6))

# %%
s
# Out:
# {(4, 5, 6), 1, 2, 3, 4, 5, 6, 'p', 'situ'}

# %%
s.update({6,7,8})

# %%
s.discard(4)

# %%
s
# Out:
# {(4, 5, 6), 1, '123', 2, 3, 5, 6, 7, 8, 'p', 'situ'}

# %%
s.pop()
# Out:
# 3

# %%
s
# Out:
# {(4, 5, 6), '123', 5, 6, 7, 8, 'p', 'situ'}

# %%
d={'a':2,'b':3}

# %%
d['kgf']=1300

# %%
d
# Out:
# {'a': 2, 'b': 3, 'kgf': 1300}

# %%
d.update(['55','77'])

# %%
d
# Out:
# {'a': 2, 'b': 3, 'kgf': 1300, '5': '5', '7': '7'}

# %%
d.pop('kgf')
# Out:
# 1300

# %%
d
# Out:
# {'a': 2, '7': '7'}

# %%
d.popitem()
# Out:
# ('7', '7')

# %%
d
# Out:
# {'a': 2}
