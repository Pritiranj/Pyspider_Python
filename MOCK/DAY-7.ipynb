# %%
#Armstrong Number

def arm(num,power):
    
    if num ==0:
        return 0
    return (num%10)**power+arm(num//10,power)
num=153
power=len(str(num))
if arm(num,power)==num:
    print('yes')
else:
    print('no')
# Out:
# yes

# %%
# # hsappy number(Function)
# def pro(num,res=0):
#     while num != 0:
#         rem=num%10
#         res=res+rem**2
#         num//=10
#     return res
# def happy(num):
#     while num > 9:
#         num=pro(num)
#     if num==1 or num==7:
#         return 'yes'
#     return 'no'
# num=10
# print(happy(num))


# Recursion

def squ(num):
    if num==0:
        return 0
    return (num%10)**2+squ(num//10)

def che(num):
    if num >9:
        return che(squ(num))
    return num
num=100
sid=che(num)
if sid==1 or sid==7:
    print('yes')
else:
    print('no')
# Out:
# yes

# %%
#strong number
