# %%
s='it is raining'
word=''
res=[]
for ch in s:
    if ch==' ':
        res+=[word]
    else:
        word=ch+word
res+=[word]
print(res)
rev=''
ind=0
while ind != len(res):
    if ind != len(res)-1:
        rev+=res[ind]+' '
    else:
        rev+=res[ind]
print(rev)
# Out:
# ['ti', 'siti', 'gniniarsiti']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 13
#      11 rev=''
#      12 ind=0
# ---> 13 while ind != len(res):
#      14     if ind != len(res)-1:
#      15         rev+=res[ind]+' '
#
# KeyboardInterrupt:

# %%
s = 'it is raining'
word = ''
res = []
for ch in s:
    if ch == ' ':
        res += [word]
    else:
        word = ch + word
res += [word]
# print(res)

rev = ''
ind = 0
while ind != len(res):
    if ind != len(res) - 1:
        rev += res[ind] + ' '
    else:
        rev += res[ind]
print(rev)

# %%
s='hai python'
d={}
for i in s:
    if i not in d:
        d[i]=1
    else:
        d[i]+=1
a=max(d.values())
for ele in d:
    if d[ele]==a:
        print(ele)
# Out:
# h

# %%
def fibo(n,a,b):
    print(a)
    if n>1:
        print(b)
    for i in range(2,n):
        c=a+b
        print(c)
        a,b=b,c
fibo(5,1,2)
# Out:
# 1
# 2
# 3
# 5
# 8

# %%
l=[1,9,8,0,5]
for ind1 in range(len(l)-1,0,-1):
    for ind2 in range(ind1):
        if l[ind2]>l[ind2+1]:
            l[ind2],l[ind2+1]=l[ind2+1],l[ind2]
print(l)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 4
#       2 for ind1 in range(len(l)-1,0,-1):
#       3     for ind2 in range(ind1,len(l)):
# ----> 4         if l[ind2]>l[ind2+1]:
#       5             l[ind2],l[ind2+1]=l[ind2+1],l[ind2]
#       6 print(l)
#
# IndexError: list index out of range

# %%
l=[1,9,8,0,5]
for ind1 in range(len(l)-1):
    li=ind1
    for ind2 in range(ind1+1,len(l)):
        if l[li]>l[ind2]:
            li=ind2
    l[ind1],l[li]=l[li],l[ind1]
print(l)
# Out:
# [0, 1, 5, 8, 9]

# %%
l=['kumar', 'somu', 'sonu', 'ram', 'raju']
l1=[]
for ele in l:
    l1.append(ele[0])
d={}

for ch in l1:
    if ch not in d:
        d[ch]=1
    else:
        d[ch]+=1
print(d)
# Out:
# {'k': 1, 's': 2, 'r': 2}

# %%
l1 = [1, 2, 3]
l2 = [2, 4, 6]
result = []

for i in range(len(l1)):
    result+=[(l1[i] + l2[i])]

print(result)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 6
#       3 result = []
#       5 for i in range(len(l1)):
# ----> 6     result+=[(l1[i] + l2[i])]
#       8 print(result)
#
# IndexError: list index out of range
